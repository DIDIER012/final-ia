# %%
#instalar gemini
# %pip install -U google-generativeai 
# instalar open ia
# %pip install openai==0.28  
#importar gemini
import google.generativeai as genai  
# importar openia
import openai 
# necesario para las repuestas
import requests 
import os # necesario importar para carga un conjunto de funciones y variables que permiten interactuar con el sistema
# Out:
# Requirement already satisfied: google-generativeai in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (0.7.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (0.6.6)
# Requirement already satisfied: google-api-core in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.19.1)
# Requirement already satisfied: google-api-python-client in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.139.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.32.0)
# Requirement already satisfied: protobuf in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.25.4)
# Requirement already satisfied: pydantic in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.8.2)
# Requirement already satisfied: tqdm in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-ai-generativelanguage==0.6.6->google-generativeai) (1.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai) (1.63.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\acer\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.65.4)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai==0.28 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (4.66.5)
# Requirement already satisfied: aiohttp in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2024.7.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: colorama in c:\users\acer\appdata\roaming\python\python312\site-packages (from tqdm->openai==0.28) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
openai.api_key = "" 
genai.configure(api_key="")

# %%
# Configuración del modelo generativo  
generation_config = {  
    "temperature": 1,  
    "top_p": 0.95,  
    "top_k": 64,  
    "max_output_tokens": 8192,  
    "response_mime_type": "text/plain",  
}  

# Inicialización del modelo  
model = genai.GenerativeModel(  
    model_name="gemini-1.5-flash",  
    generation_config=generation_config,  
    system_instruction="Eres un experto en programación e informática, el cual brinda apoyo y posible soluciones a bugs o problemas específicos que el usuario no entienda. A demás si lo requiere, optimiza el código.",  
)  
# Lugar de guardado del chat
history_chat = []  
#creacion de imagen con open ia

def generate_image(prompt):  
    response = openai.Image.create(  
        prompt=prompt,  
        n=1,  
        size="1024x1024"  
    )  
    return response['data'][0]['url']  
def chat():  
    chat_session = model.start_chat(history=history_chat)  
    
    print("Soy tu asistente de código, estoy aquí para ayudarte en lo que necesites. Puedo ayudarte con bugs, errores de sintaxis, optimización, etc.")  
    while True:   
        user_message = input("Tu: ")  

        if user_message.lower() == "salir":   
            break  

        if not user_message.strip():  
            print("Por favor, ingresa un mensaje no vacío.")  
            continue  

        response = chat_session.send_message(user_message)  
        response_text = getattr(response, 'text', 'No se pudo obtener respuesta del modelo.')  
        print(response_text)  

        history_chat.append({'role': 'user', 'parts': [user_message]})  
        history_chat.append({'role': 'model', 'parts': [response_text]})  

        # Generación de la imagen automáticamente  
        try:  
            image_url = generate_image(user_message)  
            if image_url:  
                print(f"Image URL: {image_url}")  
                history_chat.append({'role': 'model', 'parts': [f"Image URL: {image_url}"]})  
        except Exception as e:  
            print(f"Error al generar la imagen: {e}")  

# Inicia la conversación  
chat()
# Out:
# Soy tu asistente de código, estoy aquí para ayudarte en lo que necesites. Puedo ayudarte con bugs, errores de sintaxis, optimización, etc.
# Hola! 👋 ¿En qué puedo ayudarte hoy? 😊
#
# Cuéntame sobre el problema que estás teniendo con tu código, ya sea un bug, un error específico, o incluso si simplemente no entiendes cómo funciona algo.
#
# Puedo ayudarte a:
#
# * **Identificar el error:** Te ayudaré a entender qué causa el problema.
# * **Encontrar soluciones:**  Te daré ideas sobre cómo solucionar el error.
# * **Optimizar tu código:** Si lo necesitas, puedo ayudarte a hacer que tu código sea más eficiente.
#
# ¡Estoy aquí para ayudarte a resolver cualquier problema que tengas con tu código! 💻
#
# Error al generar la imagen:
#
# You tried to access openai.Image, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
#
# ¡Ahí hay un pequeño error! 😉  En JavaScript, la palabra clave `const` se usa para declarar una **constante**, que es una variable cuyo valor no se puede cambiar después de ser definida.
#
# En tu caso, estás intentando asignar la función `console.log("hola mundo")` a una constante llamada `const`.  No se puede hacer eso directamente.
#
# **Aquí hay cómo corregir tu código:**
#
# ```javascript
# console.log("hola mundo");
# ```
#
# Ahora, la función `console.log()` se ejecutará y mostrará "hola mundo" en la consola.
#
# **Recuerda:**
#
# * Las constantes se declaran con `const`.
# * Las variables que pueden cambiar se declaran con `let`.
#
# Espero que esto te ayude! 😄
#
# Error al generar la imagen:
#
# You tried to access openai.Image, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 58
#      55             print(f"Error al generar la imagen: {e}")
#      57 # Inicia la conversación
# ---> 58 chat()
#
# Cell In[16], line 32, in chat()
#      30 print("Soy tu asistente de código, estoy aquí para ayudarte en lo que necesites. Puedo ayudarte con bugs, errores de sintaxis, optimización, etc.")
#      31 while True:
# ---> 32     user_message = input("Tu: ")
#      34     if user_message.lower() == "salir":
#      35         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
